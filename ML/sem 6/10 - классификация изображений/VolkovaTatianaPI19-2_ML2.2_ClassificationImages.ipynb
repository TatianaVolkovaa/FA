# %% [markdown]
# ## Волкова Татьяна ПИ19-2
# ### ML2.1 Классификация изображений

# %%
from sklearn.datasets import fetch_olivetti_faces
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import seaborn as sns
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import learning_curve
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
import time

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1.	Загрузите датасет Olivetti faces;
# #### 2.	Познакомьтесь с описанием и структурой датасета. Описание можно найти в документации.

# %%
faces = fetch_olivetti_faces()
print(faces.DESCR)
# Out:
# .. _olivetti_faces_dataset:
#
# The Olivetti faces dataset
# --------------------------
#
# `This dataset contains a set of face images`_ taken between April 1992 and
# April 1994 at AT&T Laboratories Cambridge. The
# :func:`sklearn.datasets.fetch_olivetti_faces` function is the data
# fetching / caching function that downloads the data
# archive from AT&T.
#
# .. _This dataset contains a set of face images: http://www.cl.cam.ac.uk/research/dtg/attarchive/facedatabase.html
#
# As described on the original website:
#
#     There are ten different images of each of 40 distinct subjects. For some
#     subjects, the images were taken at different times, varying the lighting,
#     facial expressions (open / closed eyes, smiling / not smiling) and facial
#     details (glasses / no glasses). All the images were taken against a dark
#     homogeneous background with the subjects in an upright, frontal position
#     (with tolerance for some side movement).
#
# ...

# %% [markdown]
# #### 3.	Выведите информацию о количественных параметрах датасета;

# %%
faces['data'].shape
# Out:
# (400, 4096)

# %%
faces['images'].shape
# Out:
# (400, 64, 64)

# %%
faces['target'].shape
# Out:
# (400,)

# %% [raw]
# 400 изображений
# 40 людей

# %% [markdown]
# #### 4.	Выведите несколько изображений на экран используя инструментарий библиотеки matplotlib;

# %%
plt.imshow(faces['images'][0], cmap=plt.cm.bone)

# %%
plt.imshow(faces['images'][250], cmap=plt.cm.bone)

# %%
plt.imshow(faces['images'][399], cmap=plt.cm.bone)

# %%
n = 5
fig, axs = plt.subplots(n, n, figsize=(25, 25))
for i in range(n):
    for j in range(n):
        axs[i][j].imshow(faces['images'][i * n + j], cmap=plt.cm.bone)

# %% [markdown]
# #### 5.	Разделите эти данные на тестовую и обучающую выборки;

# %%
# матрица пикселей
X = faces['data']
# oтношение данных к конкретному классу (всего 40 классов - 40 человек)
Y = faces['target']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=True)
#X, Y

# %% [markdown]
# #### 6.	Постройте модель классификатора метода опорных векторов для идентификации человека по изображению;

# %%
svc_model = SVC()
svc_model.fit(x_train, y_train)
y_svc_pred = svc_model.predict(x_test)

# %%
fig, ax = plt.subplots(figsize=(15, 10))

ticks = np.arange(len(y_test))

#Добавлем ось x
plt.xticks(ticks, y_test)
#Добавляем ось y
plt.yticks(ticks, y_test)

#Строим матрицу при помощи sns
sns.heatmap(pd.DataFrame(metrics.confusion_matrix(y_test, y_svc_pred)), annot=True)
plt.ylabel('Действительные значения')
plt.xlabel('Предсказанные значения')
plt.show()

# %% [markdown]
# #### 7.	Оцените качество модели на тестовой выборке с помощью следующих метрик:
#
# a.	достоверность предсказания (accuracy);
#
# b.	точность (precision);
#
# c.	полнота (recall);

# %%
print('Метрика достоверности предсказания ->> ', metrics.accuracy_score(y_test, y_svc_pred))
print('Метрика точности ->> ', metrics.precision_score(y_test, y_svc_pred, average='weighted'))
print('Метрика полноты ->> ', metrics.recall_score(y_test, y_svc_pred, average='macro'))
# average - ?
# Out:
# Метрика достоверности предсказания ->>  0.8375
# Метрика точности ->>  0.8120833333333334
# Метрика полноты ->>  0.8183760683760684

# %%
print(metrics.classification_report(y_test, y_svc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         1
#            3       0.00      0.00      0.00         0
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       0.60      1.00      0.75         3
#            7       0.00      0.00      0.00         1
#            8       0.50      1.00      0.67         3
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         1
#           12       1.00      0.50      0.67         2
#           13       1.00      1.00      1.00         2
#           15       0.00      0.00      0.00         0
#           16       1.00      1.00      1.00         1
# ...

# %% [markdown]
# #### 8.	Постройте кривую обучения - график зависимости тестовой и обучающей эффективности от размера обучающей выборки.

# %%
# из файла кривые валидации и обучения
def plot_with_err(x, data, **kwargs):
    mu, std = data.mean(1),data.std(1)
    lines = plt.plot(x, mu, '-', **kwargs)
    plt.fill_between(x, mu - std, mu + std, edgecolor='none',
    facecolor=lines[0].get_color(), alpha=0.2)

# %%
def print_learning_curve(model, x_train, y_train, train_sizes=np.linspace(0.1, 1, 30)):
    _, train_scores, test_scores = learning_curve(model, x_train, y_train, train_sizes=train_sizes, cv=3)
    plt.title(model)
    plt.xlabel('train size')
    plt.ylabel('score')
    #plt.plot(train_sizes, np.mean(train_scores, axis=1), label='Training scores')
    #plt.plot(train_sizes, np.mean(test_scores, axis=1), label='Validation scores')
    plot_with_err(train_sizes, train_scores, label='Training scores')
    plot_with_err(train_sizes, test_scores, label='Validation scores', color='g')
    plt.legend()
    plt.show()

# %%
print(print_learning_curve(svc_model, x_train, y_train))
# Out:
# None

# %% [markdown]
# #### 9.	Сделайте вывод о применимости модели.

# %% [raw]
# Для очень небольшого набора данных модель по метрикам получилась неплохой. Но точности 0.8 недостаточно для реального применения (защита, подтверждение личности, нахождение преступников).

# %% [markdown]
# ### Контрольные вопросы
# 1.	Какие выводы мы можем сделать на основании метрик модели, построенной в данной лабораторной работе?
#
# Все метрики достаточно высоки >80%, но всё же точности 0.8 недостаточно для реального применения (защита, подтверждение личности)
#
# 2.	Как представляется изображение в методах машинного обучения? От чего зависит размерность вектора признаков?
#
# Можно разными способами превратить изображение в набор признаков. Самый простой способ - представить изображение как линейную последовательность пикселей.
# Если изображение черно-белое (в градациях серого), то значением признака, соответствующего каждому пикселю можно взять яркость этого пикселя. Если изображение цветное, то каждому пикселю может соответствовать три разных признака.
#
# Размерность вектора признаков зависит от разрешения изображения, от того черно-белое оно или цветное
#
# 3.	Какие задачи можно решать при помощи анализа изображений? Какие из них самые распространенные?
#
# Распознование лица - Face Id для разблокировки мобильных устройств, Face Pay — это способ для полностью бесконтактной оплаты проезда
#
# Поиск по картинке в google
#
# 4.	Какие известные датасеты изображений существуют? Для каких задач они применяются?
#
# Датасет Olivetti faces - это один из известных модельных наборов данных для обучения методам классификации изображений. Его можно получить с помощью стандартных средств sklearn
#
# На Kaggle.com можно найти датасеты с изображениями
# Pokemon Image Dataset,Rice Image Dataset, Natural Images (A compiled dataset of 6899 images from 8 distinct classes)

# %% [markdown]
# ### Дополнительные задания
# 1.	Постройте модели классификации на основе следующих методов:
#
# - логистическая регрессия (LogisticRegression);
#
# - метод опорных векторов с гауссовым ядром (SVC);
#
# - метод опорных векторов с полиномиальным ядром (SVC);
#
# - метод k ближайших соседей (KNeighborsClassifier);
#
# - многослойный перцептрон (MLP);
#
# 2.	Проанализируйте метрики каждой модели и сделайте выводы об их эффективности и применимости. Сравните эффективность всех этих моделей и выберите лучшую;
#
# 3.	Для каждой модели из п.3 постройте кривые обучения и диагностируйте недо-/переобучение модели. Попробуйте изменить параметр регуляризации для улучшения результатов модели.
#
# 4.	Сделайте замеры времени обучения для каждой модели. Сделайте вывод о сравнительной производительности моделей.

# %%
def analyze_model(model, x_train=x_train, x_test=x_test, y_train=y_train, y_test=y_test):
    
    start = time.time()
    model.fit(x_train, y_train)
    end = time.time()
    print('Время обучения ->> ', round(end - start, 2))
    
    y_pred = model.predict(x_test)
    
    fig, ax = plt.subplots(figsize=(15, 10))
    print("Матрица ошибок")
    ticks = np.arange(len(y_test))
    #Добавлем ось x
    plt.xticks(ticks, y_test)
    #Добавляем ось y
    plt.yticks(ticks, y_test)
    #Строим матрицу при помощи sns
    sns.heatmap(pd.DataFrame(metrics.confusion_matrix(y_test, y_pred)), annot=True)
    plt.ylabel('Действительные значения')
    plt.xlabel('Предсказанные значения')
    plt.show()
    
    print('Метрика достоверности предсказания ->> ', metrics.accuracy_score(y_test, y_pred))
    print('Метрика точности ->> ', metrics.precision_score(y_test, y_pred, average='weighted'))
    print('Метрика полноты ->> ', metrics.recall_score(y_test, y_pred, average='macro'))
    
    print(print_learning_curve(model, x_train, y_train))

# %% [markdown]
# #### логистическая регрессия (LogisticRegression)

# %%
log_model = LogisticRegression()
analyze_model(log_model)
# Out:
# Время обучения ->>  4.39
# Матрица ошибок
# Метрика достоверности предсказания ->>  0.9625
# Метрика точности ->>  0.965625
# Метрика полноты ->>  0.9078947368421053
# None

# %% [markdown]
# #### метод опорных векторов с полиномиальным ядром (SVC)

# %%
poly_svc_model = SVC(kernel='poly')
analyze_model(poly_svc_model)
# Out:
# Время обучения ->>  0.34
# Матрица ошибок
# Метрика достоверности предсказания ->>  0.9375
# Метрика точности ->>  0.9172916666666666
# Метрика полноты ->>  0.881578947368421
# None

# %% [markdown]
# #### метод k ближайших соседей (KNeighborsClassifier)

# %%
neigh_model = KNeighborsClassifier()
analyze_model(neigh_model)
# Out:
# Время обучения ->>  0.01
# Матрица ошибок
# Метрика достоверности предсказания ->>  0.8125
# Метрика точности ->>  0.8608630952380952
# Метрика полноты ->>  0.7863247863247863
# None

# %% [markdown]
# #### многослойный перцептрон (MLP)

# %%
mlp_model = MLPClassifier()
analyze_model(mlp_model)
# Out:
# Время обучения ->>  5.58
# Матрица ошибок
# Метрика достоверности предсказания ->>  0.0
# Метрика точности ->>  0.0
# Метрика полноты ->>  0.0

# %% [markdown]
# ### Вывод
#
# Лучше всего себя показала модель логистической регрессии - все метрики выше 0.9. Быстрее всего обучается модель метод k ближайших соседей, однако как мне кажется, гораздо важнее точность моделей, поэтому следует выбрать модель логистической регрессии.
#
#
# Хуже всего многослойный перцептрон - метрики очень низкие 0.3-0.4, что в два раза меньше, чем у всех остальных моделей. И обучалась модель гораздо дольше остальных. Также на графике кривых обучения мы можем видеть что модель переобучилась
