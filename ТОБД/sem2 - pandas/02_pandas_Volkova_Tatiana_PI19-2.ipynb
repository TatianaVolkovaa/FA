# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %%
import pandas as pd

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
df = pd.read_csv("./data/sp500hst.txt", sep = ',',  header = None,
                 names = ["date", "ticker", "open", "high","low", "close", "volume"])
df
# Out:
#             date ticker   open     high     low  close  volume
# 0       20090821      A  25.60  25.6100  25.220  25.55   34758
# 1       20090824      A  25.64  25.7400  25.330  25.50   22247
# 2       20090825      A  25.50  25.7000  25.225  25.34   30891
# 3       20090826      A  25.32  25.6425  25.145  25.48   33334
# 4       20090827      A  25.50  25.5700  25.230  25.54   70176
# ...          ...    ...    ...      ...     ...    ...     ...
# 122569  20100813    ZMH  51.72  51.9000  51.380  51.44   14561
# 122570  20100816    ZMH  51.13  51.4700  50.600  51.00   13489
# 122571  20100817    ZMH  51.14  51.6000  50.890  51.21   20498
# 122572  20100819    ZMH  51.63  51.6300  50.170  50.22   18259
# 122573  20100820    ZMH  50.03  50.5500  49.480  49.82   17792
#
# [122574 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
df[["open", "high", "low", "close", "volume"]].loc[3:6].mean()
# Out:
# open         25.485000
# high         25.750625
# low          25.328750
# close        25.632500
# volume    48567.000000
# dtype: float64

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
pd.to_datetime(df['date'], format = "%Y%m%d").dt.month
# Out:
# 0         8
# 1         8
# 2         8
# 3         8
# 4         8
#          ..
# 122569    8
# 122570    8
# 122571    8
# 122572    8
# 122573    8
# Name: date, Length: 122574, dtype: int64

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %%
df['ticker'].str.lower().head()
# Out:
# 0    a
# 1    a
# 2    a
# 3    a
# 4    a
# Name: ticker, dtype: object

# %%
df.groupby('ticker')['open'].mean()
# Out:
# ticker
# A        30.234857
# AA       13.086959
# AAPL    221.342427
# ABC      27.432122
# ABT      50.996776
#            ...
# XTO      44.640338
# YHOO     15.854774
# YUM      37.456898
# ZION     19.694057
# ZMH      56.220980
# Name: open, Length: 524, dtype: float64

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %%
sp = pd.read_csv("./data/sp_data2.csv", sep = ";", names = ["ticker","company", "percent"])
sp
# Out:
#     ticker          company percent
# 0     AAPL            Apple    3.6%
# 1     AMZN       Amazon.com    3.2%
# 2    GOOGL         Alphabet    3.1%
# 3     GOOG         Alphabet    3.1%
# 4     MSFT        Microsoft    3.0%
# ..     ...              ...     ...
# 500    SCG            SCANA    0.0%
# 501    AIZ         Assurant    0.0%
# 502    AYI    Acuity Brands    0.0%
# 503    HRB        H&R Block    0.0%
# 504    RRC  Range Resources    0.0%
#
# [505 rows x 3 columns]

# %%
df.merge(sp, how = 'inner', left_on = "ticker", right_on = 'ticker')
# Out:
#            date ticker   open     high     low  close  volume  \
# 0      20090821      A  25.60  25.6100  25.220  25.55   34758
# 1      20090824      A  25.64  25.7400  25.330  25.50   22247
# 2      20090825      A  25.50  25.7000  25.225  25.34   30891
# 3      20090826      A  25.32  25.6425  25.145  25.48   33334
# 4      20090827      A  25.50  25.5700  25.230  25.54   70176
# ...         ...    ...    ...      ...     ...    ...     ...
# 82167  20100813   ZION  20.17  20.4300  19.840  19.89   25193
# 82168  20100816   ZION  19.81  19.9600  19.600  19.95   25914
# 82169  20100817   ZION  20.07  20.4700  19.830  20.31   31717
# 82170  20100819   ZION  19.83  20.0000  19.130  19.35   45935
# 82171  20100820   ZION  19.15  19.2700  18.810  19.14   37225
#
#                     company percent
# 0      Agilent Technologies    0.1%
# 1      Agilent Technologies    0.1%
# 2      Agilent Technologies    0.1%
# 3      Agilent Technologies    0.1%
# ...

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`df2 =

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами.

# %%
recipes = pd.read_csv("./data/recipes_sample.csv", sep = ',')
reviews = pd.read_csv("./data/reviews_sample.csv", sep = ',')
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print("RECIPES: \n lines -> ", recipes.shape[0], 
      "\n columns -> ", recipes.shape[1],
      "\n types ->\n", recipes.dtypes)

print("\nREVIEWS: \n lines -> ", reviews.shape[0], 
      "\n columns -> ", reviews.shape[1],
      "\n types ->\n", reviews.dtypes)
# Out:
# RECIPES:
#  lines ->  30000
#  columns ->  8
#  types ->
#  name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
#
# REVIEWS:
#  lines ->  126696
#  columns ->  6
#  types ->
#  Unnamed: 0     int64
# user_id        int64
# recipe_id      int64
# date          object
# rating         int64
# review        object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
rec_col_na = recipes.isna().sum()
print("RECIPES:\n", rec_col_na)
print(rec_col_na[rec_col_na != 0].shape[0] / rec_col_na.shape[0] * 100, "%\n")

rew_col_na = reviews.isna().sum()
print("REVIEWS:\n", rew_col_na)
print(rew_col_na[rew_col_na != 0].shape[0] / rew_col_na.shape[0] * 100, "%")
# Out:
# RECIPES:
#  name                      0
# id                        0
# minutes                   0
# contributor_id            0
# submitted                 0
# n_steps               11190
# description             623
# n_ingredients          8880
# description_length      623
# name_word_count           0
# dtype: int64
# 40.0 %
#
# REVIEWS:
#  Unnamed: 0     0
# user_id        0
# recipe_id      0
# date           0
# rating         0
# review        17
# dtype: int64
# 16.666666666666664 %

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print("RECIPES:\n", recipes[["minutes","n_steps","n_ingredients"]].mean())
print("\nREVIEWS:\n rating          ", reviews["rating"].mean())
# Out:
# RECIPES:
#  minutes          123.358133
# n_steps            9.805582
# n_ingredients      9.008286
# dtype: float64
#
# REVIEWS:
#  rating           4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes["name"].sample(10)
# Out:
# 16129                             light coffee frappuccino
# 29733                              yummy banana  cake roll
# 11136                               florida sunshine salad
# 9723                         earl s mediterranean linguini
# 23566                                       savory burgers
# 16388                            lovely spanakotiropitakia
# 8787     crumbled goat cheese red beet and green bean t...
# 21456        potato  kale  and kielbasa casserole  for two
# 22042                    rsti with parma ham and emmenthal
# 14481                            individual spinach pizzas
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
#они же и так с нуля
reviews_ = reviews.set_index("Unnamed: 0")
reviews_.index.name = "id"
reviews_
# Out:
#             user_id  recipe_id        date  rating  \
# id
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# id
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
reviews_.reset_index()
# Out:
#              id     user_id  recipe_id        date  rating  \
# 0        370476       21752      57993  2003-05-01       5
# 1        624300      431813     142201  2007-09-16       5
# 2        187037      400708     252013  2008-01-10       4
# 3        706134  2001852463     404716  2017-12-11       5
# 4        312179       95810     129396  2008-03-14       5
# ...         ...         ...        ...         ...     ...
# 126691  1013457     1270706     335534  2009-05-17       4
# 126692   158736     2282344       8701  2012-06-03       0
# 126693  1059834      689540     222001  2008-04-08       5
# 126694   453285  2000242659     354979  2015-06-02       5
# 126695   691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[(recipes["minutes"] <= 20) & (recipes["n_ingredients"] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes["submitted"] = pd.to_datetime(recipes["submitted"], format = "%Y-%m-%d")
recipes.dtypes
# Out:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %%
recipes = pd.read_csv("./data/recipes_sample.csv", sep = ",", 
                       parse_dates = ["submitted"])
recipes.dtypes
# Out:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes["submitted"] <= "31-12-2010"]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
recipes[recipes["submitted"].dt.year <= 2010]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes["description_length"] = recipes["description"].str.len()
recipes[:3]
# Out:
#                                                     name      id  minutes  \
# 26223  Subru uncle s whole green moong dal i ll be ma...   77188       95
# 26222  Subru uncle s toor ki dal sindhi style  dad  m...   76908       65
# 27876  Top secret recipes version of  i h o p  griddl...  113346       20
#
#        contributor_id  submitted  n_steps  \
# 26223            6357 2003-11-21      NaN
# 26222            6357 2003-11-18     29.0
# 27876          175727 2005-03-14      5.0
#
#                                              description  n_ingredients  \
# 26223  my dad and mom quite enjoy this lentil curry. ...           15.0
# 26222  this is the lentil curry that subru uncle(our ...           15.0
# 27876  this recipe is top secret recipes version of i...            9.0
#
#        description_length  name_word_count
# 26223               343.0               15
# 26222              1087.0               14
# 27876               129.0               14

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes["name"] = recipes["name"].str.capitalize()
recipes[:3]
# Out:
#                                                     name      id  minutes  \
# 26223  Subru uncle s whole green moong dal i ll be ma...   77188       95
# 26222  Subru uncle s toor ki dal sindhi style  dad  m...   76908       65
# 27876  Top secret recipes version of  i h o p  griddl...  113346       20
#
#        contributor_id  submitted  n_steps  \
# 26223            6357 2003-11-21      NaN
# 26222            6357 2003-11-18     29.0
# 27876          175727 2005-03-14      5.0
#
#                                              description  n_ingredients  \
# 26223  my dad and mom quite enjoy this lentil curry. ...           15.0
# 26222  this is the lentil curry that subru uncle(our ...           15.0
# 27876  this recipe is top secret recipes version of i...            9.0
#
#        description_length  name_word_count
# 26223               343.0               15
# 26222              1087.0               14
# 27876               129.0               14

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами).

# %%
recipes["name_word_count"] = recipes["name"].str.split().str.len()
recipes[:3]
# Out:
#                                                     name      id  minutes  \
# 26223  Subru uncle s whole green moong dal i ll be ma...   77188       95
# 26222  Subru uncle s toor ki dal sindhi style  dad  m...   76908       65
# 27876  Top secret recipes version of  i h o p  griddl...  113346       20
#
#        contributor_id  submitted  n_steps  \
# 26223            6357 2003-11-21      NaN
# 26222            6357 2003-11-18     29.0
# 27876          175727 2005-03-14      5.0
#
#                                              description  n_ingredients  \
# 26223  my dad and mom quite enjoy this lentil curry. ...           15.0
# 26222  this is the lentil curry that subru uncle(our ...           15.0
# 27876  this recipe is top secret recipes version of i...            9.0
#
#        description_length  name_word_count
# 26223               343.0               15
# 26222              1087.0               14
# 27876               129.0               14

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
contr_rec_num = recipes.groupby("contributor_id")["id"].count().sort_values()
print(contr_rec_num)
print("\ncontributor with max rec -> ", contr_rec_num.idxmax())
# Out:
# contributor_id
# 302190      1
# 449247      1
# 449229      1
# 449014      1
# 448748      1
#          ...
# 169430    183
# 1533      186
# 37779     345
# 37449     346
# 89831     421
# Name: id, Length: 8404, dtype: int64
#
# contributor with max rec ->  89831

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы?

# %%
print(reviews.groupby("recipe_id")["rating"].mean())
print("\nrecipes without review -> ", reviews[reviews["review"].isna()].shape[0])
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64
#
# recipes without review ->  17

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipes.groupby(recipes["submitted"].dt.year)["id"].count()
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# Name: id, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты без отзывов должны отсутствовать в данной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и выведя на экран строку из полученного `DataFrame`, содержащую информацию об этом отзыве.

# %%
rec_rew = recipes[["id", "name"]].merge(reviews[["user_id", "recipe_id", "rating"]],
                                       how = "inner", 
                                       left_on = "id",
                                       right_on = "recipe_id",
                                       )
rec_rew.drop("recipe_id", 1).sort_values("rating")
# Out:
#             id                             name     user_id  rating
# 63347   301564  Chunky oatmeal cookies  freezer      484122       0
# 80978   372130          No crust buttermilk pie  2002271290       0
# 80975    25947            Ann lander s meatloaf       67358       0
# 80972    25947            Ann lander s meatloaf  2002246240       0
# 80941   252246          Smoked salmon egg salad      455641       0
# ...        ...                              ...         ...     ...
# 63629   264043         Cinnamon and raisin oats      464080       5
# 63628   264043         Cinnamon and raisin oats      383346       5
# 63627   264043         Cinnamon and raisin oats      149363       5
# 63625   264043         Cinnamon and raisin oats       37305       5
# 126695  143615                         Caramels      646764       5
#
# [126696 rows x 4 columns]

# %%
reviews.groupby("recipe_id")["review"].count().sort_values()
# Out:
# recipe_id
# 388773       1
# 378545       1
# 171832       1
# 171849       1
# 378445       1
#           ...
# 50719      486
# 107786     591
# 135350     674
# 82102      708
# 27208     1382
# Name: review, Length: 28100, dtype: int64

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`. У рецептов, для которых отсутствуют отзывы, в соответствущем столбце должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и выведя на экран строку из полученного `DataFrame`, содержащую информацию об этом отзыве.

# %%
review_count = reviews.groupby("recipe_id")["review"].count()
result = recipes[["id", "name"]].merge(review_count,
                            how = "left",
                            left_on = "id",
                            right_on = "recipe_id")
result = result.fillna(0)
result.sort_values("review")
# Out:
#            id                                               name  review
# 29230    9360                                      Canned salmon     0.0
# 26923  355068                                      Crimson drink     0.0
# 21717  398227                           French canadian tourtire     0.0
# 7296   324679                        Spicy crock pot pulled pork     0.0
# 21713  307645                               Persian basmati rice     0.0
# ...       ...                                                ...     ...
# 13094   50719                     The sweetest blueberry muffins   486.0
# 451    107786      Beth s melt in your mouth barbecue ribs  oven   591.0
# 3154   135350    Fannie farmer s classic baked macaroni   cheese   674.0
# 434     82102  Kittencal s moist cheddar garlic oven fried ch...   708.0
# 4487    27208                         To die for crock pot roast  1382.0
#
# [30000 rows x 3 columns]

# %% [markdown]
# 5.3. Выясните, отзывы, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
reviews["date"] = pd.to_datetime(reviews["date"], format = "%Y-%m-%d")
#print(reviews.groupby(reviews["date"].dt.year)["rating"].mean().sort_values())
reviews.groupby(reviews["date"].dt.year)["rating"].mean().idxmin()
# Out:
# 2017

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes = recipes.sort_values(by = "name_word_count", ascending = False)
recipes
# Out:
#                                                     name      id  minutes  \
# 26223  Subru uncle s whole green moong dal i ll be ma...   77188       95
# 26222  Subru uncle s toor ki dal sindhi style  dad  m...   76908       65
# 27876  Top secret recipes version of  i h o p  griddl...  113346       20
# 28083  Tsr version of t g i  friday s black bean soup...  102274       75
# 22778  Roasted garlic stuffed steak with garlic mashe...   38409       85
# ...                                                  ...     ...      ...
# 23016                                             Rotini  207839       35
# 23063                                             Runzas   55733       45
# 4340                                              Caesar   52399        1
# 21111                                           Pomidori  353387        2
# 4710                                            Caramels  143615       30
#
#        contributor_id  submitted  n_steps  \
# ...

# %%
recipes.to_csv("./data/new_recipes.csv")

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter(r"./data/6.2.xlsx") as writer:
    rec_rew.to_excel(writer, sheet_name = "Рецепты с оценками")
    result.to_excel(writer, sheet_name = "Количество отзывов по рецептам")
